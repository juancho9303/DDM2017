# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from astropy.table import Table
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.neighbors import KernelDensity
#from numpy import linearalgebra as LA
from scipy import linalg as LA

# %matplotlib inline

# %%
data = Table.read("/net/gooimeer/data1/juan/DBDM/DDM2017/Datasets/x-vs-y-for-PCA.csv")

# %%
#print data

# %%
plt.plot(data['x'],data['y'], 'o')
plt.show()

# %%
#Standardise

x_new = (data['x']-np.mean(data['x']))/np.std(data['x'])
y_new = (data['y']-np.mean(data['y']))/np.std(data['y'])

# %%
#Calculate the covariance matrix

XY = np.array([x_new, y_new])
cov_matrix = np.cov(XY)

f, (ax1, ax2) = plt.subplots(1,2, sharey=True)
ax1.plot(data['x'], data['y'], 'o')
ax2.imshow(cov_matrix, origin = 'lower', interpolation='none')

# %%
w,v = LA.eig(cov_matrix)
print cov_matrix
print v.real
plt.imshow(v.real, origin="lower", interpolation='none')
# Out:
# [[ 1.02564103  0.99718328]
#  [ 0.99718328  1.02564103]]
# [[-0.70710678 -0.70710678]
#  [ 0.70710678 -0.70710678]]

# %%
plt.plot(data['x'], data['y'], '*')
#plt.plot(x_new, y_new, '*')
#plt.plot(v)

plt.quiver(v[0], v[1], scale=8)

print w
# Out:
# [ 0.02845774+0.j  2.02282431+0.j]

# %%
pcs = np.zeros((2,len(x_new)))
for i in range(len(x_new)):
    pcs[:,i] = np.matmul(v.T, np.array([x_new[i], y_new[i]]).T)

# %%
#scatter(pcs[0], pcs[1])
plt.plot(pcs[0], pcs[1], 'o')

# %%
pcs_1 = np.zeros((2,len(x_new)))
for i in range(len(x_new)):
    pcs_1[:,i] = np.matmul(v[0], np.array([x_new[i], y_new[i]]).T)
plt.plot(pcs_1[0], pcs_1[1], 'o')

# %%
#

x_back = pcs_1*v[0][0] * np.std(data['x'])+np.mean(data['x'])
y_back = pcs_1*v[0][1] * np.std(data['y'])+np.mean(data['y'])

plt.scatter(x_back, y_back)
plt.plot(data['x'], data['y'], 'r^')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
pca = PCA(whiten=False, n_components=2)

X = np.vstack([data['x'],data['y']]).T
scl = StandardScaler()
Xs = scl.fit_transform(X)

pca.fit(Xs)

ev1_1, ev2_1 = zip(*pca.components_.T)
ev1_1, ev2_1
# Out:
# ((0.70710678118654746, 0.70710678118654768),
#  (0.70710678118654768, -0.70710678118654746))

# %%
Xs_back = pca.inverse_transform(Xs)
#print Xs_back

plt.scatter(Xs_back*ev1_1[0]*np.std(data['x'])+np.mean(data['x']), Xs_back*ev1_1[1]* np.std(data['y'])+np.mean(data['y']))
plt.plot(data['x'], data['y'], 'r^')
